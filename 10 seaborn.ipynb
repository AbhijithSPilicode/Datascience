# %%
import seaborn as sns 
# %matplotlib inline 
#it will give the things in image itself

# %%
tips=sns.load_dataset("tips")
tips #inbuilt dataset which will have both numerical and categorical data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#displot #show a set of distribution

# %%
sns.displot(tips["total_bill"])

# %%
sns.displot(tips["total_bill"],bins=5)

# %%
sns.distplot(tips["total_bill"],bins=5) #older version of displot
# Out:
# C:\Users\user\anaconda3\envs\pythomopencv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
  #JOINTPLOT

# %%
#Distribution of 2 variables together

# %%
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde") #2d

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg") #regression value

# %%
sns.set_palette("viridis")
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.set_palette("viridis_r")
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex") # _r reverse the colour palettetip"

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex",palette="rocket")

# %%
sns.set_palette("viridis")  #to change colour
sns.rugplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.displot(tips["total_bill"],bins=5,rug=True)

# %%
sns.relplot(x="total_bill",y="tip",data=tips) #default it will be scatter

# %%
sns.set_palette("viridis_r")
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,style="time",hue="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,style="time",size="size")

# %%
sns.set_palette("tab10")  #this is for default colour
sns.relplot(x="total_bill",y="tip",data=tips,style="time",size="size",sizes=(10,100),hue="sex")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,style="time",size="size",sizes=(10,100),hue="sex",aspect=2)

# %%
sns.relplot(x="total_bill",y="tip",data=tips,size="size",sizes=(10,100),hue="sex",style="smoker",col="day",col_wrap=2)

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day",col="time")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="day",col="time",row="sex")

# %%
sns.relplot(x="size",y="total_bill",data=tips,kind="line")

# %%
sns.relplot(x="size",y="total_bill",data=tips,kind="line",ci="sd")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
fmri=sns.load_dataset("fmri") #inbuilt dataset
fmri.head(2)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883

# %%
fmri["subject"].value_counts()
# Out:
# s11    76
# s10    76
# s8     76
# s2     76
# s6     76
# s0     76
# s5     76
# s13    76
# s1     76
# s7     76
# s12    76
# s9     76
# s4     76
# s3     76
# Name: subject, dtype: int64

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",estimator=None)

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",hue="event")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",hue="event",style="region")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",hue="region",style="event",markers=True,dashes=False)

# %%
sns.relplot(x="timepoint",y="signal",hue="region",units="subject",estimator=None,kind="line",data=fmri.query("event=='stim'"))

# %%
#categorical plots

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#here sex,smoker,day,time,size are categorical

# %%
#plotting one categorical data against one numerical data

# %%
sns.barplot(x="sex",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex",y="total_bill",order=["Female","Male"],data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x="sex",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",hue="smoker",dodge=False,data=tips) #the category will be stacked
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips) #violin will be defines as kernel density
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y="day",x="total_bill",data=tips) #violin will be defines as kernel density
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(y="day",x="total_bill",inner="stick",data=tips) #rugplot
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",split=True,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",split=True,inner="quartile",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#stripplot    #for small datasets,it will give points

# %%
sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",jitter=False,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",hue="sex",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",hue="sex",dodge=True,data=tips)
#dodge is to sperate subcategories
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#swarmplot

# %%
sns.swarmplot(x="day",y="total_bill",data=tips) #like violinplot of stripplot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
sns.swarmplot(x="day",y="total_bill",data=tips,color="black") #like violinplot of stripplot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,scale="count")
sns.swarmplot(x="day",y="total_bill",data=tips,color="black") #like violinplot of stripplot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#catlpot

# %%
sns.catplot(x="day",y="total_bill",data=tips) #by default it will be stripplot

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="swarm",dodge=True,hue="sex")
# Out:
# C:\Users\user\anaconda3\envs\pythomopencv\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="box",dodge=True,hue="sex")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="violin",dodge=True,hue="sex")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="bar",dodge=True,hue="sex")

# %%
sns.catplot(x="day",data=tips,kind="count")

# %%
#matrixplot

# %%
t=tips.corr()
t
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(t)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(t,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(t,cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %%
flight=sns.load_dataset("flights")
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df=flight.pivot_table(index="month",columns="year",values="passengers")

# %%
sns.heatmap(df,cmap="magma")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,cmap="viridis")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,cmap="viridis_r") #colourmap of viridis will be reversed
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(df,cmap="viridis_r",linecolor="white",linewidths=.09) #seperate the bricks from one another
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(df,cmap="viridis")

# %%
sns.clustermap(df,cmap="viridis",standard_scale=1)

# %%
iris=sns.load_dataset("iris")

# %%
p=sns.PairGrid(iris)
p.map(sns.scatterplot)

# %%
p=sns.PairGrid(iris)
p.map_diag(sns.histplot)  #diagonal histogram,resst scatter
p.map_offdiag(sns.scatterplot)

# %%
p=sns.PairGrid(iris)
p.map_diag(sns.histplot)    #diaginal
p.map_lower(sns.scatterplot)  #upperdiagonal
p.map_upper(sns.kdeplot)     #lower diagonal

# %%
p=sns.PairGrid(iris,hue="species")
p.map_diag(sns.histplot)    #diaginal
p.map_lower(sns.scatterplot)  #upperdiagonal
p.map_upper(sns.kdeplot)#lower diagonal
p.add_legend()

# %%
f=sns.FacetGrid(iris)

# %%
f=sns.FacetGrid(iris)
f.map(sns.scatterplot,"sepal_length","sepal_width")

# %%
f=sns.FacetGrid(iris)
f.map(sns.kdeplot,"sepal_length")
